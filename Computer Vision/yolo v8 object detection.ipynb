# %% [markdown]
# # Вариант 5 Object Detection

# %%
import os
import zipfile

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
zip_file = '/content/drive/MyDrive/archive.zip'
z = zipfile.ZipFile(zip_file, 'r')
z.extractall()
print(os.listdir())
# Out:
# ['.config', 'drive', 'custom_data.yaml', 'train', 'val', 'sample_data']

# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 779.6/779.6 kB 4.4 MB/s eta 0:00:00
# ...

# %% [markdown]
# # Данные - скриншоты из шутера CS:GO
# Скриншоты были размечены с использованием следующих лейблов - голова террориста, тело террориста, голова контртеррориста и тело контртеррориста
# train - 337 изображений
# validation - 90 изображений

# %%
from ultralytics import YOLO

model = YOLO('yolov8n.pt')

results = model.train(
   data='data_custom.yaml',
   imgsz=640,
   epochs=15,
   batch=8,
   name='yolov8n_mini_custom',
    plots=True)
# Out:
# Ultralytics YOLOv8.2.28 🚀 Python-3.10.12 torch-2.3.0+cpu CPU (Intel Xeon 2.00GHz)
# ...

# %% [markdown]
# # Предсказание

# %%
from ultralytics import YOLO
from PIL import Image


model = YOLO("/content/runs/detect/yolov8n_mini_custom5/weights/best.pt") # path to .pt model file

results = model("/content/cstest.png")

for r in results:
    im_array = r.plot()
    im = Image.fromarray(im_array[..., ::-1])
    im.save('results.jpg')
# Out:
# image 1/1 /content/cstest.png: 384x640 2 ct_bodys, 2 t_bodys, 2 t_heads, 98.4ms
# Speed: 3.0ms preprocess, 98.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)

# %%
import cv2
from google.colab.patches import cv2_imshow
cv2_imshow(cv2.imread("cstest.png"))
# Out:
# <PIL.Image.Image image mode=RGB size=800x450>

# %%
cv2_imshow(cv2.imread("results.jpg"))
# Out:
# <PIL.Image.Image image mode=RGB size=800x450>
